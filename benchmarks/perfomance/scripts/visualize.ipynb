# %%
# !ls
# Out:
# visualize.ipynb

# %%
import json
import pandas as pd

# %%
with open("../ll.json", "r") as f:
    sclaene_json = json.load(f)

# %%
import importlib
import utils
importlib.reload(utils)
from utils import get_perfomance_dataframe

dff = get_perfomance_dataframe(sclaene_json, top=1)

# %%
dff.head(20)
# Out:
#                                                                                                                                                                                                                line  \
# file                                               total_time percent_cpu_time function                          function_n_cpu_percent_all function_n_copy_mb_s
# /home/marti/projects/etna-ts/etna/models/catboo... 14.966313  80.842687        _CatBoostModel.fit                365.831847                 4.770376                                   self.model.fit(train_pool)\n
# /home/marti/projects/etna-ts/etna/transforms/ba... 14.966313  5.905761         PerSegmentWrapper.transform       3.740723                   0.000000                               _idx.insert(0, "segment", key)\n
# ...
